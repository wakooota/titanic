# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns,set()

#csvファイルをダウンロード
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
#Pclass（チケットランク）別の生存率
sns.countplot(x = 'Pclass', hue = 'Survived', data = train)
plt.show()
 #→クラスが高いほど生存率は高い

# %%
#Sex(性別)ごとの生存率
sns.countplot(x = 'Sex', hue = 'Survived', data = train)
plt.show()
#→女性の方が生存率は高い

# %%
#Age(年齢)ごとの生存率
cmap = plt.get_cmap('tab10')
fig, ax = plt.subplots(1, 2, figsize=(15, 6))
train[train['Survived']==0]['Age'].ax[0, 1].plot(kind='hist', bins=50, title='Dead')
train[train['Survived']==1]['Age'].ax[0, 0].plot(kind='hist', bins=50, title='Alive')

ax[0, 1].plt.ylabel('Count')
ax[0, 1].plt.ylim(0 , 40)
ax[0, 1].plt.show()

ax[0, 0].plt.ylabel('Count')
ax[0, 0].plt.ylim(0 , 40)
ax[0, 0].plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-69810bbcf54f> in <cell line: 4>()
#       2 cmap = plt.get_cmap('tab10')
#       3 fig, ax = plt.subplots(1, 2, figsize=(15, 6))
# ----> 4 train[train['Survived']==0]['Age'].ax[0, 1].plot(kind='hist', bins=50, title='Dead')
#       5 train[train['Survived']==1]['Age'].ax[0, 0].plot(kind='hist', bins=50, title='Alive')
#       6
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'ax'

# %%
#Sibsp(同乗している兄弟、配偶者の数)ごとの生存率
#Parch（同乗している兄弟、配偶者の数）ごとの生存率
#Ticket（チケット番号）のヒストグラム
#Fare（運賃）のヒストグラム
#Embarked（出向港）ごとの生存率
sns.barplot(x='Embarked', y='Survived', data=train, palette='Set1')
